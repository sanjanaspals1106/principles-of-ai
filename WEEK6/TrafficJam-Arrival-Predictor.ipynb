# %%
pip install pgmpy
# Out:
# Collecting pgmpy
#   Downloading pgmpy-1.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting huggingface_hub>=0.23 (from pgmpy)
#   Downloading huggingface_hub-1.8.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: networkx>=3.0 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (3.4.2)
# Requirement already satisfied: numpy>=2.0 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (2.1.3)
# Requirement already satisfied: scipy>=1.10 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.2 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (1.7.1)
# Requirement already satisfied: pandas>=1.5 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (2.2.3)
# Collecting statsmodels>=0.14.5 (from pgmpy)
#   Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: tqdm>=4.64 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (4.67.1)
# Requirement already satisfied: pyparsing>=3.0 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (3.2.0)
# Requirement already satisfied: joblib>=1.2 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (1.4.2)
# Requirement already satisfied: opt_einsum>=3.3 in c:\users\administrator\anaconda3\lib\site-packages (from pgmpy) (3.4.0)
# Collecting scikit-base>=0.12.4 (from pgmpy)
#   Downloading scikit_base-0.13.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: filelock>=3.10.0 in c:\users\administrator\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\administrator\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (2025.3.2)
# Collecting hf-xet<2.0.0,>=1.4.2 (from huggingface_hub>=0.23->pgmpy)
#   Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\administrator\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\administrator\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\administrator\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (6.0.2)
# Requirement already satisfied: typer in c:\users\administrator\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\administrator\anaconda3\lib\site-packages (from huggingface_hub>=0.23->pgmpy) (4.12.2)
# Requirement already satisfied: anyio in c:\users\administrator\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (4.7.0)
# Requirement already satisfied: certifi in c:\users\administrator\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\administrator\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (1.0.9)
# Requirement already satisfied: idna in c:\users\administrator\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\administrator\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrator\anaconda3\lib\site-packages (from pandas>=1.5->pgmpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\anaconda3\lib\site-packages (from pandas>=1.5->pgmpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrator\anaconda3\lib\site-packages (from pandas>=1.5->pgmpy) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.5->pgmpy) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\administrator\anaconda3\lib\site-packages (from scikit-learn>=1.2->pgmpy) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\administrator\anaconda3\lib\site-packages (from statsmodels>=0.14.5->pgmpy) (1.0.1)
# Requirement already satisfied: colorama in c:\users\administrator\anaconda3\lib\site-packages (from tqdm>=4.64->pgmpy) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\administrator\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub>=0.23->pgmpy) (1.3.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\administrator\anaconda3\lib\site-packages (from typer->huggingface_hub>=0.23->pgmpy) (8.1.8)
# Downloading pgmpy-1.1.0-py3-none-any.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------- ----- 2.1/2.4 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 10.9 MB/s eta 0:00:00
# Downloading huggingface_hub-1.8.0-py3-none-any.whl (625 kB)
#    ---------------------------------------- 0.0/625.2 kB ? eta -:--:--
#    --------------------------------------- 625.2/625.2 kB 11.4 MB/s eta 0:00:00
# Downloading hf_xet-1.4.3-cp37-abi3-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ---------------------- ----------------- 2.1/3.7 MB 10.8 MB/s eta 0:00:01
#    ------------------------------- -------- 2.9/3.7 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 3.4/3.7 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 5.3 MB/s eta 0:00:00
# Downloading scikit_base-0.13.1-py3-none-any.whl (159 kB)
# Downloading statsmodels-0.14.6-cp313-cp313-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.5 MB 8.7 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.5 MB 9.2 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.5 MB 9.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------------- ------- 7.9/9.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 6.5 MB/s eta 0:00:00
# Installing collected packages: scikit-base, hf-xet, statsmodels, huggingface_hub, pgmpy
#
#    ---------------------------------------- 0/5 [scikit-base]
#    -------- ------------------------------- 1/5 [hf-xet]
#   Attempting uninstall: statsmodels
#    -------- ------------------------------- 1/5 [hf-xet]
#     Found existing installation: statsmodels 0.14.4
#    -------- ------------------------------- 1/5 [hf-xet]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#     Uninstalling statsmodels-0.14.4:
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#       Successfully uninstalled statsmodels-0.14.4
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ---------------- ----------------------- 2/5 [statsmodels]
#    ------------------------ --------------- 3/5 [huggingface_hub]
#    ------------------------ --------------- 3/5 [huggingface_hub]
#    ------------------------ --------------- 3/5 [huggingface_hub]
#    ------------------------ --------------- 3/5 [huggingface_hub]
#    ------------------------ --------------- 3/5 [huggingface_hub]
#    ------------------------ --------------- 3/5 [huggingface_hub]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    -------------------------------- ------- 4/5 [pgmpy]
#    ---------------------------------------- 5/5 [pgmpy]
#
# Successfully installed hf-xet-1.4.3 huggingface_hub-1.8.0 pgmpy-1.1.0 scikit-base-0.13.1 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.

# %%
from pgmpy.models import DiscreteBayesianNetwork
from pgmpy.estimators import ParameterEstimator
from pgmpy.inference import VariableElimination
import pandas as pd

# %%
data = pd.DataFrame({
    'Rain': [
        'Yes','Yes','Yes','Yes','No','No','No','No',
        'Yes','Yes','No','No'
    ],
    'TrafficJam': [
        'Yes','Yes','No','Yes','No','No','Yes','No',
        'Yes','No','Yes','No'
    ],
    'ArriveLate': [
        'Yes','Yes','No','Yes','No','No','Yes','No',
        'Yes','No','Yes','No'
    ]
})

# %%
model = DiscreteBayesianNetwork([('Rain', 'TrafficJam'), ('TrafficJam', 'ArriveLate')])

# %%
model.fit(data)

# %%
print(model.get_cpds())
# Out:
# [<TabularCPD representing P(Rain:2) at 0x19b2f8969f0>, <TabularCPD representing P(TrafficJam:2 | Rain:2) at 0x19b2f896d50>, <TabularCPD representing P(ArriveLate:2 | TrafficJam:2) at 0x19b2f896de0>]

# %%
inference = VariableElimination(model)
query_result = inference.query(variables=['ArriveLate'], evidence={'Rain': 'Yes'})
print(query_result)
# Out:
# +-----------------+-------------------+
# | ArriveLate      |   phi(ArriveLate) |
# +=================+===================+
# | ArriveLate(No)  |            0.3333 |
# +-----------------+-------------------+
# | ArriveLate(Yes) |            0.6667 |
# +-----------------+-------------------+
